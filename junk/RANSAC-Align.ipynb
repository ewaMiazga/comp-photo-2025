# %% [markdown]
# ## 00. Imports

# %%
import cv2
import numpy as np
import rawpy
import matplotlib.pyplot as plt

# %% [markdown]
# ## 01. RANSAC on RAW photos

# %%
import cv2
import numpy as np
import rawpy
import matplotlib.pyplot as plt

def read_image(filename):
    """Reads an image in full color. Supports RAW and JPG/PNG formats."""
    if filename.lower().endswith(('.nef', '.cr2', '.arw', '.dng', '.rw2')):  # RAW formats
        with rawpy.imread(filename) as raw:
            rgb = raw.postprocess()  # Process RAW file to RGB
        image = cv2.cvtColor(rgb, cv2.COLOR_RGB2BGR)  # Convert to OpenCV BGR format
    else:  # JPG/PNG
        image = cv2.imread(filename)
    
    if image is None:
        raise ValueError(f"Failed to read image: {filename}")
    
    return image

def align_images(img1, img2):
    """Aligns img2 to img1 using ORB feature matching and RANSAC."""
    orb = cv2.ORB_create(5000)

    # Convert images to grayscale for feature detection
    img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    img2_gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

    # Detect keypoints and descriptors
    kp1, des1 = orb.detectAndCompute(img1_gray, None)
    kp2, des2 = orb.detectAndCompute(img2_gray, None)

    # Match features using BFMatcher
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    matches = bf.match(des1, des2)
    matches = sorted(matches, key=lambda x: x.distance)  # Sort by distance

    # Use RANSAC to find homography
    if len(matches) > 10:
        src_pts = np.float32([kp2[m.trainIdx].pt for m in matches]).reshape(-1, 1, 2)
        dst_pts = np.float32([kp1[m.queryIdx].pt for m in matches]).reshape(-1, 1, 2)
        
        H, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC, 5.0)
        
        # Warp img2 to align with img1 (preserving colors)
        aligned_img = cv2.warpPerspective(img2, H, (img1.shape[1], img1.shape[0]))
        
        return aligned_img, H
    else:
        raise ValueError("Not enough matches found.")

# Example usage
DIR = "first-dataset/first-dataset-RAW/"
image1_path = f"{DIR}IMG_7781.CR2"  # Change to your RAW/JPG file path
image2_path = f"{DIR}IMG_7782.CR2"  # Change to your RAW/JPG file path

img1 = read_image(image1_path)
img2 = read_image(image2_path)

aligned_img, homography = align_images(img1, img2)

# Convert BGR to RGB for correct color display in Matplotlib
img1_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
aligned_img_rgb = cv2.cvtColor(aligned_img, cv2.COLOR_BGR2RGB)

# Show results
plt.figure(figsize=(12, 5))

plt.subplot(1, 3, 1)
plt.imshow(img1_rgb)
plt.title("Reference Image")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(img2_rgb)
plt.title("Unaligned Image")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(aligned_img_rgb)
plt.title("Aligned Image")
plt.axis('off')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# LibRawIOError                             Traceback (most recent call last)
# Cell In[2], line 56
#      53 image1_path = f"{DIR}IMG_7781.CR2"  # Change to your RAW/JPG file path
#      54 image2_path = f"{DIR}IMG_7782.CR2"  # Change to your RAW/JPG file path
# ---> 56 img1 = read_image(image1_path)
#      57 img2 = read_image(image2_path)
#      59 aligned_img, homography = align_images(img1, img2)
#
# Cell In[2], line 9, in read_image(filename)
#       7 """Reads an image in full color. Supports RAW and JPG/PNG formats."""
#       8 if filename.lower().endswith(('.nef', '.cr2', '.arw', '.dng', '.rw2')):  # RAW formats
# ----> 9     with rawpy.imread(filename) as raw:
#      10         rgb = raw.postprocess()  # Process RAW file to RGB
#      11     image = cv2.cvtColor(rgb, cv2.COLOR_RGB2BGR)  # Convert to OpenCV BGR format
#
# File c:\Users\ewa.miazga\miniconda3\envs\mlbd\envs\ml_clean\lib\site-packages\rawpy\__init__.py:20, in imread(pathOrFile)
#      18     d.open_buffer(pathOrFile)
#      19 else:
# ---> 20     d.open_file(pathOrFile)
#      21 return d
#
# File rawpy\\_rawpy.pyx:413, in rawpy._rawpy.RawPy.open_file()
#
# File rawpy\\_rawpy.pyx:955, in rawpy._rawpy.RawPy.handle_error()
#
# LibRawIOError: b'Input/output error'

# %% [markdown]
# ## 02. RANSAC on JPG photos

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def read_image(filename):
    """Reads a JPG/PNG image in color (BGR format)."""
    image = cv2.imread(filename)
    if image is None:
        raise ValueError(f"Failed to read image: {filename}")
    return image

def align_images(img1, img2):
    """Aligns img2 to img1 using ORB feature matching and RANSAC."""
    orb = cv2.ORB_create(5000)

    # Convert images to grayscale for feature detection
    img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    img2_gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

    # Detect keypoints and descriptors
    kp1, des1 = orb.detectAndCompute(img1_gray, None)
    kp2, des2 = orb.detectAndCompute(img2_gray, None)

    # Match features using BFMatcher
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    matches = bf.match(des1, des2)
    matches = sorted(matches, key=lambda x: x.distance)  # Sort by distance

    # Use RANSAC to find homography
    if len(matches) > 10:
        src_pts = np.float32([kp2[m.trainIdx].pt for m in matches]).reshape(-1, 1, 2)
        dst_pts = np.float32([kp1[m.queryIdx].pt for m in matches]).reshape(-1, 1, 2)
        
        H, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC, 5.0)
        
        # Warp img2 to align with img1 (preserving colors)
        aligned_img = cv2.warpPerspective(img2, H, (img1.shape[1], img1.shape[0]))
        
        return aligned_img, H
    else:
        raise ValueError("Not enough matches found.")

# Example usage
DIR = "first-dataset/first-dataset-JPG/"
image1_path = f"{DIR}IMG_7781_DxO.JPG"
image2_path = f"{DIR}IMG_7782_DxO.JPG"  

img1 = read_image(image1_path)
img2 = read_image(image2_path)

aligned_img, homography = align_images(img1, img2)

# Convert BGR to RGB for correct color display in Matplotlib
img1_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
aligned_img_rgb = cv2.cvtColor(aligned_img, cv2.COLOR_BGR2RGB)

# Show results
plt.figure(figsize=(12, 5))

plt.subplot(1, 3, 1)
plt.imshow(img1_rgb)
plt.title("Reference Image")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(img2_rgb)
plt.title("Unaligned Image")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(aligned_img_rgb)
plt.title("Aligned Image")
plt.axis('off')

plt.show()
